# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib notebook

# %%
data = np.loadtxt('test.txt',delimiter=',')

# %%
data.shape
# Out:
# (257, 164)

# %%
mag = (data[:,::2]**2 + data[:,1::2]**2)**0.5
phase = np.arctan(data[:,1::2]/data[:,0::2])
phase2 = np.arctan2(data[:,1::2],data[:,0::2])
# Out:
# /Users/nams/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/nams/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
plt.figure(1)
plt.clf()
plt.plot(mag[0,:],'o-')
plt.xlabel('sample')
plt.ylabel('magnitude')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'magnitude')

# %%
plt.figure(2)
plt.plot(phase[-1,:],'o-')
plt.plot(phase2[-1,:],'+-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(3)
idx = 0
plt.plot(data[idx,::2], data[idx,1::2],'o')
plt.axis('square')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-137.5, 137.5, -137.5, 137.5)

# %%
plt.figure(4)
ax = plt.axes(projection='3d')
xline = data[idx,::2][::2]
yline = data[idx,1::2][::2]
zline = np.arange(len(xline))
# ax.plot3D(xline, yline, zline, 'gray')
ax.scatter3D(xline, yline, zline, 'b');
xline = data[idx,::2][1::2]
yline = data[idx,1::2][1::2]
zline = np.arange(len(xline))
# ax.plot3D(xline, yline, zline, 'gray')
ax.scatter3D(xline, yline, zline, 'r');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.diff(phase2[0,:])
